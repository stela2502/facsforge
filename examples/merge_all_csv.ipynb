# %%
from pathlib import Path
import pandas as pd
import anndata
from facsforge.core.index import load_index_csv
import os
import glob

# %%
# INPUT folders
INDEX_DIR = Path("./")
BARCODE_XLSX = Path("../Sequencing/Well-ID_S8-Sort.xlsx")
ADATA_PATH = Path("../First_salamander_batch_analyzed.adata")

# OUTPUT
OUT_CSV = Path("facs_index_merged.csv")
OUT_ADATA = Path("First_salamander_batch_analyzed_with_facs.h5ad")

# Column contract
CELL_ID_COL     = "cell_id"   # target unified ID
WELL_COL        = "Well"
BARCODE_COL     = "barcode"
SORT_FLAG_COL   = "Well"

# %%
os.getcwd()
# Out:
# '/home/med-sal/BMC_Projects/Leigh/Marlene/Phagozytosis_FACS_Seq/BioInformatics_IntegrationOfFACS-DataANDscRNA-Seq/RAW_Sort-data'

# %%
f"{INDEX_DIR}/*.csv"
# Out:
# './*.csv'

# %%
glob.glob(f"{INDEX_DIR}/*.csv")
# Out:
# ['./E2-E3.csv',
#  './P24.csv',
#  './A1-B10.csv',
#  './E1.csv',
#  './A7-A12.csv',
#  './A24-A23.csv',
#  './C9.csv',
#  './C8-E4.csv',
#  './A13-A24.csv',
#  './J16-O5.csv',
#  './O4-P23.csv',
#  './B11-C10.csv',
#  './F1-J15.csv']

# %%
def load_all_sorted_csvs(folder: Path):
    frames = []
    for csv in folder.glob("*.csv"):
        print(f"Loading {csv.name}")
        df = load_index_csv(csv)   # ✅ YOUR API
        df["__source_file"] = csv.name
        frames.append(df)

    all_cells = pd.concat(frames, axis=0, ignore_index=True)
    return all_cells

# %%
df_index = load_all_sorted_csvs(INDEX_DIR)
df_index.head()
# Out:
# Loading E2-E3.csv
# Loaded index CSV E2-E3.csv: 2 rows, removed 382 zero rows.
# Loading P24.csv
# Loaded index CSV P24.csv: 1 rows, removed 383 zero rows.
# Loading A1-B10.csv
# Loaded index CSV A1-B10.csv: 16 rows, removed 368 zero rows.
# Loading E1.csv
# Loaded index CSV E1.csv: 1 rows, removed 383 zero rows.
# Loading A7-A12.csv
# Loaded index CSV A7-A12.csv: 6 rows, removed 378 zero rows.
# Loading A24-A23.csv
# Loaded index CSV A24-A23.csv: 2 rows, removed 382 zero rows.
# Loading C9.csv
# Loaded index CSV C9.csv: 1 rows, removed 383 zero rows.
# Loading C8-E4.csv
# Loaded index CSV C8-E4.csv: 53 rows, removed 331 zero rows.
# Loading A13-A24.csv
# Loaded index CSV A13-A24.csv: 12 rows, removed 372 zero rows.
# Loading J16-O5.csv
# Loaded index CSV J16-O5.csv: 125 rows, removed 259 zero rows.
# Loading O4-P23.csv
# Loaded index CSV O4-P23.csv: 27 rows, removed 357 zero rows.
# Loading B11-C10.csv
# Loaded index CSV B11-C10.csv: 29 rows, removed 355 zero rows.
# Loading F1-J15.csv
# Loaded index CSV F1-J15.csv: 111 rows, removed 273 zero rows.
#   Well  EventID Sort Population  \
# 0  E02        1  Leukocytes 1-3
# 1  E03        1  Leukocytes 1-3
# 2  P24        1  Leukocytes 2-2
# 3  A01        1  Erythrocytes 1
# 4  A02        1  Erythrocytes 1
#
#                                           ImagePath  EventIndex      Time  \
# 0     images\E2-E3_E02_Leukocytes 1-3_00001624.tiff        1624    8.0775
# 1     images\E2-E3_E03_Leukocytes 1-3_00001301.tiff        1301    5.7294
# 2       images\P24_P24_Leukocytes 2-2_00000970.tiff         970   12.4942
# 3  images\Sort_003_A01_Erythrocytes 1_00014065.tiff       14065  125.6402
# 4  images\Sort_003_A02_Erythrocytes 1_00011974.tiff       11974  102.9451
#
#        FSC-A  FSC-H  FSC-W  SSC (Violet)-A  ...  EventNumber  DeltaTime  \
# 0   48192072  35821   1345        17417544  ...      1187404     144294
# 1   48734760  30120   1618         4906290  ...      1187081     267876
# 2   41336260  37630   1098         8144450  ...      1363747    6789746
# 3   85159640  34788   2447         2900781  ...       994472     165914
# 4  107748880  53907   1998        27843924  ...       992381    2290597
#
#    DropId  SaturatedChannels1  SaturatedChannels2  SpectralEventWidth  \
# 0       0                   0                   0                5189
# 1       0                   0                   0                6845
# 2       0                   0                   0                4790
# 3       0                   0                   0                6962
# 4       0                   0                   0                5415
#
#    EventWidthInDrops  SpectralUnmixingFlags  WaveformPresent  __source_file
# 0                  0                      0                0      E2-E3.csv
# 1                  0                      0                0      E2-E3.csv
# 2                  0                      0                0        P24.csv
# 3                  0                      0                0     A1-B10.csv
# 4                  0                      0                0     A1-B10.csv
#
# [5 rows x 422 columns]

# %%
def mark_double_sorts(df, key):
    counts = df[key].value_counts()
    doubles = counts[counts > 1].index

    df["double_sorted"] = df[key].isin(doubles)

    print(f"Double-sorted events: {df['double_sorted'].sum()}")
    return df, doubles

# %%
df_index, DUP_IDS = mark_double_sorts(df_index, "Well")
DUP_IDS
# Out:
# Double-sorted events: 4
# Index(['A23', 'A24'], dtype='object', name='Well')

# %%
df_barcode = pd.read_excel(BARCODE_XLSX)
df_barcode.head()
# Out:
#   BCset   plateBC              XC_DNBPE           XC_DNBPE_TS WellID  \
# 0    8E  11280436  AGTCACCGAATGCTTGTCGT  AGGTATAGCTTGCTTGTCGT     A1
# 1    8E  11280436  AGTCACCGAATGTCTGAAGG  AGGTATAGCTTGTCTGAAGG    A10
# 2    8E  11280436  AGTCACCGAAGCCAAGAATC  AGGTATAGCTGCCAAGAATC    A11
# 3    8E  11280436  AGTCACCGAAAGCAGTTAGC  AGGTATAGCTAGCAGTTAGC    A12
# 4    8E  11280436  AGTCACCGAAAAGCTGACCA  AGGTATAGCTAAGCTGACCA    A13
#
#                          S8_Sort  gate  phagocytosing no phagocytosing
# 0  Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 1  Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 2  Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 3  Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 4  Low_Phagocytosis_Erythrocytes   NaN                             NaN

# %%
def normalize_well(w):
    if pd.isna(w):
        return None
    row = w[0].upper()
    col = int(w[1:])
    return f"{row}{col:02d}"

# %%
df_barcode["Well_norm"] = df_barcode["WellID"].apply(normalize_well)

# %%
df_index["Well_norm"] = df_index["Well"].apply(normalize_well)

# %%
merged =df_barcode.merge(df_index ,left_on="Well_norm",right_on="Well_norm")
merged
# Out:
#     BCset   plateBC              XC_DNBPE           XC_DNBPE_TS WellID  \
# 0      8E  11280436  AGTCACCGAATGCTTGTCGT  AGGTATAGCTTGCTTGTCGT     A1
# 1      8E  11280436  AGTCACCGAATGTCTGAAGG  AGGTATAGCTTGTCTGAAGG    A10
# 2      8E  11280436  AGTCACCGAAGCCAAGAATC  AGGTATAGCTGCCAAGAATC    A11
# 3      8E  11280436  AGTCACCGAAAGCAGTTAGC  AGGTATAGCTAGCAGTTAGC    A12
# 4      8E  11280436  AGTCACCGAAAAGCTGACCA  AGGTATAGCTAAGCTGACCA    A13
# ..    ...       ...                   ...                   ...    ...
# 381    8E  11280436  GTAGACGAAGGCAAGACTCA  TGCGATTATGGCAAGACTCA     P5
# 382    8E  11280436  GTAGACGAAGGACATCACCT  TGCGATTATGGACATCACCT     P6
# 383    8E  11280436  GTAGACGAAGCATCAGGATC  TGCGATTATGCATCAGGATC     P7
# 384    8E  11280436  GTAGACGAAGACGTCTGAAC  TGCGATTATGACGTCTGAAC     P8
# 385    8E  11280436  GTAGACGAAGATGCAGAAGG  TGCGATTATGATGCAGAAGG     P9
#
#                            S8_Sort  gate  phagocytosing no phagocytosing  \
# 0    Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 1    Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 2    Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 3    Low_Phagocytosis_Erythrocytes   NaN                             NaN
# 4    Low_Phagocytosis_Erythrocytes   NaN                             NaN
# ..                             ...   ...                             ...
# 381  High_Phagocytosis_Leukocytes2   NaN                             NaN
# 382  High_Phagocytosis_Leukocytes2   NaN                             NaN
# 383  High_Phagocytosis_Leukocytes2   NaN                             NaN
# 384  High_Phagocytosis_Leukocytes2   NaN                             NaN
# 385  High_Phagocytosis_Leukocytes2   NaN                             NaN
#
#     Well_norm Well  ...  DeltaTime DropId SaturatedChannels1  \
# 0         A01  A01  ...     165914      0                  0
# 1         A10  A10  ...      37988      0                  0
# 2         A11  A11  ...    2458656      0                  0
# 3         A12  A12  ...     269849      0                  0
# 4         A13  A13  ...    2104402      0                  0
# ..        ...  ...  ...        ...    ...                ...
# 381       P05  P05  ...    2503783      0                  0
# 382       P06  P06  ...    2012759      0                  0
# 383       P07  P07  ...    3821502      0                  0
# 384       P08  P08  ...    2390977      0                  0
# 385       P09  P09  ...    2765655      0                  0
#
#      SaturatedChannels2  SpectralEventWidth  EventWidthInDrops  \
# 0                     0                6962                  0
# 1                     0                5638                  0
# 2                     0                4970                  0
# 3                     0                6386                  0
# 4                     0                7044                  0
# ..                  ...                 ...                ...
# 381                   0                5149                  0
# 382                   0                5076                  0
# 383                   0                5141                  0
# 384                   0                4903                  0
# 385                   0                4821                  0
#
#      SpectralUnmixingFlags  WaveformPresent  __source_file  double_sorted
# 0                        0                0     A1-B10.csv          False
# 1                        0                0     A7-A12.csv          False
# 2                        0                0     A7-A12.csv          False
# 3                        0                0     A7-A12.csv          False
# 4                        0                0    A13-A24.csv          False
# ..                     ...              ...            ...            ...
# 381                      0                0     O4-P23.csv          False
# 382                      0                0     O4-P23.csv          False
# 383                      0                0     O4-P23.csv          False
# 384                      0                0     O4-P23.csv          False
# 385                      0                0     O4-P23.csv          False
#
# [386 rows x 432 columns]

# %%
merged = merged [ merged['double_sorted'] == False]

# %%
adata = anndata.read_h5ad( ADATA_PATH )
adata
# Out:
# AnnData object with n_obs × n_vars = 354 × 12323
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'geneSum', 'RP[LS]sum', 'n_genes', 'leiden', 'leiden_10_overclustered', 'leiden_10_0.85', 'leiden_10_0.85_renamed', 'celltype'
#     var: 'gene_ids', 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'hvg', 'leiden', 'leiden_10_0.85_renamed_colors', 'leiden_10_0.85_renamed_stats', 'leiden_10_overclustered', 'leiden_10_overclustered_colors', 'leiden_colors', 'leiden_stats', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       n_genes_by_counts  log1p_n_genes_by_counts  \
# AACTGAACACAAGCTGACCA               5318                 8.579041
# AACTGAACACACGTCTGAAC               6768                 8.820109
# AACTGAACACAGCAGTTAGC               3591                 8.186464
# AACTGAACACAGCCGAGTTA               2710                 7.905073
# AACTGAACACAGCGATAACG               5201                 8.556798
# ...                                 ...                      ...
# TTCCTGTGACTCTGGACAGT               3009                 8.009695
# TTCCTGTGACTGCTTGTCGT               2436                 7.798523
# TTCCTGTGACTGTCTGAAGG               5410                 8.596189
# TTCCTGTGACTGTCTGACCA               5080                 8.533263
# TTCCTGTGACTTGGCCTATG                538                 6.289716
#
#                       total_counts  log1p_total_counts  \
# AACTGAACACAAGCTGACCA       23883.0           10.080964
# AACTGAACACACGTCTGAAC       61701.0           11.030071
# AACTGAACACAGCAGTTAGC       13561.0            9.515027
# AACTGAACACAGCCGAGTTA        7207.0            8.882947
# AACTGAACACAGCGATAACG       24477.0           10.105530
# ...                            ...                 ...
# TTCCTGTGACTCTGGACAGT       13992.0            9.546312
# TTCCTGTGACTGCTTGTCGT       10681.0            9.276316
# TTCCTGTGACTGTCTGAAGG       37165.0           10.523149
# TTCCTGTGACTGTCTGACCA       30644.0           10.330225
# TTCCTGTGACTTGGCCTATG         845.0            6.740520
#
#                       pct_counts_in_top_50_genes  pct_counts_in_top_100_genes  \
# AACTGAACACAAGCTGACCA                   15.534062                    21.525771
# AACTGAACACACGTCTGAAC                   25.881266                    39.524481
# AACTGAACACAGCAGTTAGC                   29.311998                    37.209645
# AACTGAACACAGCCGAGTTA                   18.828916                    25.697239
# AACTGAACACAGCGATAACG                   18.135392                    25.840585
# ...                                          ...                          ...
# TTCCTGTGACTCTGGACAGT                   35.484563                    50.371641
# TTCCTGTGACTGCTTGTCGT                   39.134912                    53.599850
# TTCCTGTGACTGTCTGAAGG                   22.233284                    31.564644
# TTCCTGTGACTGTCTGACCA                   24.928208                    33.331158
# TTCCTGTGACTTGGCCTATG                   33.727811                    45.562130
#
#                       pct_counts_in_top_200_genes  \
# AACTGAACACAAGCTGACCA                    29.518905
# AACTGAACACACGTCTGAAC                    51.655565
# AACTGAACACAGCAGTTAGC                    47.157289
# AACTGAACACAGCCGAGTTA                    35.063133
# AACTGAACACAGCGATAACG                    36.258528
# ...                                           ...
# TTCCTGTGACTCTGGACAGT                    63.221841
# TTCCTGTGACTGCTTGTCGT                    65.518210
# TTCCTGTGACTGTCTGAAGG                    43.446791
# TTCCTGTGACTGTCTGACCA                    44.054301
# TTCCTGTGACTTGGCCTATG                    60.000000
#
#                       pct_counts_in_top_500_genes  geneSum  RP[LS]sum  \
# AACTGAACACAAGCTGACCA                    44.747310  23627.0          0
# AACTGAACACACGTCTGAAC                    65.246917  49501.0          0
# AACTGAACACAGCAGTTAGC                    62.030824  12657.0          0
# AACTGAACACAGCCGAGTTA                    53.364784   7121.0          0
# AACTGAACACAGCGATAACG                    52.400212  22100.0          0
# ...                                           ...      ...        ...
# TTCCTGTGACTCTGGACAGT                    74.835620  10894.0          0
# TTCCTGTGACTGCTTGTCGT                    77.062073   8432.0          0
# TTCCTGTGACTGTCTGAAGG                    59.537199  33689.0          0
# TTCCTGTGACTGTCTGACCA                    59.939956  28262.0          0
# TTCCTGTGACTTGGCCTATG                    95.502959    823.0          0
#
#                       n_genes leiden leiden_10_overclustered leiden_10_0.85  \
# AACTGAACACAAGCTGACCA     5266      0                      23             23
# AACTGAACACACGTCTGAAC     6710      0                      40             45
# AACTGAACACAGCAGTTAGC     3533      5                      12             12
# AACTGAACACAGCCGAGTTA     2671      5                       1              1
# AACTGAACACAGCGATAACG     5143      5                       1              1
# ...                       ...    ...                     ...            ...
# TTCCTGTGACTCTGGACAGT     2951      6                       2              8
# TTCCTGTGACTGCTTGTCGT     2378      6                       2              8
# TTCCTGTGACTGTCTGAAGG     5352      8                      13             13
# TTCCTGTGACTGTCTGACCA     5022      8                      13             13
# TTCCTGTGACTTGGCCTATG      521      3                      21             21
#
#                      leiden_10_0.85_renamed                  celltype
# AACTGAACACAAGCTGACCA                      4         Myeloid / DC-like
# AACTGAACACACGTCTGAAC                      5                Macrophage
# AACTGAACACAGCAGTTAGC                      1  Megakaryocyte / Platelet
# AACTGAACACAGCCGAGTTA                     10    Megakaryocyte (mature)
# AACTGAACACAGCGATAACG                     10    Megakaryocyte (mature)
# ...                                     ...                       ...
# TTCCTGTGACTCTGGACAGT                      0  Hematopoietic progenitor
# TTCCTGTGACTGCTTGTCGT                      0  Hematopoietic progenitor
# TTCCTGTGACTGTCTGAAGG                     13  Granulocyte / Neutrophil
# TTCCTGTGACTGTCTGACCA                     13  Granulocyte / Neutrophil
# TTCCTGTGACTTGGCCTATG                      6        Monocyte / DC-like
#
# [354 rows x 16 columns]

# %%
adata.obs = adata.obs.merge(
    merged,
    right_on="XC_DNBPE_TS",
left_index= True,
    how="left"
).set_index(adata.obs.index)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 354 × 12323
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'geneSum', 'RP[LS]sum', 'n_genes', 'leiden', 'leiden_10_overclustered', 'leiden_10_0.85', 'leiden_10_0.85_renamed', 'celltype', 'BCset', 'plateBC', 'XC_DNBPE', 'XC_DNBPE_TS', 'WellID', 'S8_Sort', 'gate', 'phagocytosing no phagocytosing', 'Well_norm', 'Well', 'EventID', 'Sort Population', 'ImagePath', 'EventIndex', 'Time', 'FSC-A', 'FSC-H', 'FSC-W', 'SSC (Violet)-A', 'SSC (Violet)-H', 'SSC (Violet)-W', 'LightLoss (Imaging)-A', 'LightLoss (Imaging)-H', 'LightLoss (Imaging)-W', 'SSC (Imaging)-A', 'SSC (Imaging)-H', 'SSC (Imaging)-W', 'LightLoss (Violet)-A', 'LightLoss (Violet)-H', 'LightLoss (Violet)-W', 'E.coli Lysosom Alexa Fluor 488-A', 'L-D eF780-right*-A', 'Size (LightLoss (Imaging))', 'Size (FSC)', 'Size (SSC (Imaging))', 'Size (E.coli Lysosom Alexa Fluor 488)', 'Max Intensity (LightLoss (Imaging))', 'Max Intensity (FSC)', 'Max Intensity (SSC (Imaging))', 'Max Intensity (E.coli Lysosom Alexa Fluor 488)', 'Long Axis Moment (LightLoss (Imaging))', 'Long Axis Moment (FSC)', 'Long Axis Moment (SSC (Imaging))', 'Long Axis Moment (E.coli Lysosom Alexa Fluor 488)', 'Short Axis Moment (LightLoss (Imaging))', 'Short Axis Moment (FSC)', 'Short Axis Moment (SSC (Imaging))', 'Short Axis Moment (E.coli Lysosom Alexa Fluor 488)', 'Center of Mass (Y) (LightLoss (Imaging))', 'Center of Mass (Y) (FSC)', 'Center of Mass (Y) (SSC (Imaging))', 'Center of Mass (Y) (E.coli Lysosom Alexa Fluor 488)', 'Center of Mass (X) (LightLoss (Imaging))', 'Center of Mass (X) (FSC)', 'Center of Mass (X) (SSC (Imaging))', 'Center of Mass (X) (E.coli Lysosom Alexa Fluor 488)', 'Total Intensity (LightLoss (Imaging))', 'Total Intensity (FSC)', 'Total Intensity (SSC (Imaging))', 'Total Intensity (E.coli Lysosom Alexa Fluor 488)', 'Radial Moment (SSC (Imaging))', 'Radial Moment (LightLoss (Imaging))', 'Radial Moment (FSC)', 'Radial Moment (E.coli Lysosom Alexa Fluor 488)', 'Eccentricity (SSC (Imaging))', 'Eccentricity (LightLoss (Imaging))', 'Eccentricity (FSC)', 'Eccentricity (E.coli Lysosom Alexa Fluor 488)', 'Diffusivity (SSC (Imaging))', 'Diffusivity (LightLoss (Imaging))', 'Diffusivity (FSC)', 'Diffusivity (E.coli Lysosom Alexa Fluor 488)', 'Delta CoM (SSC (Imaging)/LightLoss (Imaging))', 'Delta CoM (SSC (Imaging)/FSC)', 'Delta CoM (SSC (Imaging)/E.coli Lysosom Alexa Fluor 488)', 'Delta CoM (LightLoss (Imaging)/FSC)', 'Delta CoM (LightLoss (Imaging)/E.coli Lysosom Alexa Fluor 488)', 'Delta CoM (FSC/E.coli Lysosom Alexa Fluor 488)', 'Saturated', 'Time.1', 'Sorted', 'Row', 'Column', 'ImgB1 (535)-A', 'ImgB2 (600)-A', 'ImgB3 (790)-A', 'UV1 (375)-A', 'UV2 (390)-A', 'UV3 (420)-A', 'UV4 (440)-A', 'UV5 (460)-A', 'UV6 (475)-A', 'UV7 (500)-A', 'UV8 (515)-A', 'UV9 (530)-A', 'UV10 (545)-A', 'UV11 (575)-A', 'UV12 (590)-A', 'UV13 (605)-A', 'UV14 (625)-A', 'UV15 (655)-A', 'UV16 (675)-A', 'UV17 (700)-A', 'UV18 (725)-A', 'UV19 (750)-A', 'UV20 (780)-A', 'UV21 (810)-A', 'UV22 (845)-A', 'V1 (420)-A', 'V2 (440)-A', 'V3 (460)-A', 'V4 (475)-A', 'V5 (500)-A', 'V6 (515)-A', 'V7 (530)-A', 'V8 (545)-A', 'V9 (575)-A', 'V10 (590)-A', 'V11 (605)-A', 'V12 (625)-A', 'V13 (655)-A', 'V14 (675)-A', 'V15 (700)-A', 'V16 (725)-A', 'V17 (750)-A', 'V18 (780)-A', 'V19 (810)-A', 'V20 (845)-A', 'B1 (500)-A', 'B2 (515)-A', 'B3 (530)-A', 'B4 (545)-A', 'B5 (575)-A', 'B6 (590)-A', 'B7 (605)-A', 'B8 (625)-A', 'B9 (655)-A', 'B10 (675)-A', 'B11 (700)-A', 'B12 (725)-A', 'B13 (750)-A', 'B14 (780)-A', 'B15 (810)-A', 'B16 (845)-A', 'YG1 (575)-A', 'YG2 (590)-A', 'YG3 (605)-A', 'YG4 (625)-A', 'YG5 (655)-A', 'YG6 (675)-A', 'YG7 (700)-A', 'YG8 (725)-A', 'YG9 (750)-A', 'YG10 (780)-A', 'YG11 (810)-A', 'YG12 (845)-A', 'R1 (655)-A', 'R2 (675)-A', 'R3 (700)-A', 'R4 (725)-A', 'R5 (750)-A', 'R6 (780)-A', 'R7 (810)-A', 'R8 (845)-A', 'ImgB1 (535)-H', 'ImgB2 (600)-H', 'ImgB3 (790)-H', 'UV1 (375)-H', 'UV2 (390)-H' ...
#     var: 'gene_ids', 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'hvg', 'leiden', 'leiden_10_0.85_renamed_colors', 'leiden_10_0.85_renamed_stats', 'leiden_10_overclustered', 'leiden_10_overclustered_colors', 'leiden_colors', 'leiden_stats', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata = adata[ adata.obs['double_sorted'] ==False].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 352 × 12323
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'geneSum', 'RP[LS]sum', 'n_genes', 'leiden', 'leiden_10_overclustered', 'leiden_10_0.85', 'leiden_10_0.85_renamed', 'celltype', 'BCset', 'plateBC', 'XC_DNBPE', 'XC_DNBPE_TS', 'WellID', 'S8_Sort', 'gate', 'phagocytosing no phagocytosing', 'Well_norm', 'Well', 'EventID', 'Sort Population', 'ImagePath', 'EventIndex', 'Time', 'FSC-A', 'FSC-H', 'FSC-W', 'SSC (Violet)-A', 'SSC (Violet)-H', 'SSC (Violet)-W', 'LightLoss (Imaging)-A', 'LightLoss (Imaging)-H', 'LightLoss (Imaging)-W', 'SSC (Imaging)-A', 'SSC (Imaging)-H', 'SSC (Imaging)-W', 'LightLoss (Violet)-A', 'LightLoss (Violet)-H', 'LightLoss (Violet)-W', 'E.coli Lysosom Alexa Fluor 488-A', 'L-D eF780-right*-A', 'Size (LightLoss (Imaging))', 'Size (FSC)', 'Size (SSC (Imaging))', 'Size (E.coli Lysosom Alexa Fluor 488)', 'Max Intensity (LightLoss (Imaging))', 'Max Intensity (FSC)', 'Max Intensity (SSC (Imaging))', 'Max Intensity (E.coli Lysosom Alexa Fluor 488)', 'Long Axis Moment (LightLoss (Imaging))', 'Long Axis Moment (FSC)', 'Long Axis Moment (SSC (Imaging))', 'Long Axis Moment (E.coli Lysosom Alexa Fluor 488)', 'Short Axis Moment (LightLoss (Imaging))', 'Short Axis Moment (FSC)', 'Short Axis Moment (SSC (Imaging))', 'Short Axis Moment (E.coli Lysosom Alexa Fluor 488)', 'Center of Mass (Y) (LightLoss (Imaging))', 'Center of Mass (Y) (FSC)', 'Center of Mass (Y) (SSC (Imaging))', 'Center of Mass (Y) (E.coli Lysosom Alexa Fluor 488)', 'Center of Mass (X) (LightLoss (Imaging))', 'Center of Mass (X) (FSC)', 'Center of Mass (X) (SSC (Imaging))', 'Center of Mass (X) (E.coli Lysosom Alexa Fluor 488)', 'Total Intensity (LightLoss (Imaging))', 'Total Intensity (FSC)', 'Total Intensity (SSC (Imaging))', 'Total Intensity (E.coli Lysosom Alexa Fluor 488)', 'Radial Moment (SSC (Imaging))', 'Radial Moment (LightLoss (Imaging))', 'Radial Moment (FSC)', 'Radial Moment (E.coli Lysosom Alexa Fluor 488)', 'Eccentricity (SSC (Imaging))', 'Eccentricity (LightLoss (Imaging))', 'Eccentricity (FSC)', 'Eccentricity (E.coli Lysosom Alexa Fluor 488)', 'Diffusivity (SSC (Imaging))', 'Diffusivity (LightLoss (Imaging))', 'Diffusivity (FSC)', 'Diffusivity (E.coli Lysosom Alexa Fluor 488)', 'Delta CoM (SSC (Imaging)/LightLoss (Imaging))', 'Delta CoM (SSC (Imaging)/FSC)', 'Delta CoM (SSC (Imaging)/E.coli Lysosom Alexa Fluor 488)', 'Delta CoM (LightLoss (Imaging)/FSC)', 'Delta CoM (LightLoss (Imaging)/E.coli Lysosom Alexa Fluor 488)', 'Delta CoM (FSC/E.coli Lysosom Alexa Fluor 488)', 'Saturated', 'Time.1', 'Sorted', 'Row', 'Column', 'ImgB1 (535)-A', 'ImgB2 (600)-A', 'ImgB3 (790)-A', 'UV1 (375)-A', 'UV2 (390)-A', 'UV3 (420)-A', 'UV4 (440)-A', 'UV5 (460)-A', 'UV6 (475)-A', 'UV7 (500)-A', 'UV8 (515)-A', 'UV9 (530)-A', 'UV10 (545)-A', 'UV11 (575)-A', 'UV12 (590)-A', 'UV13 (605)-A', 'UV14 (625)-A', 'UV15 (655)-A', 'UV16 (675)-A', 'UV17 (700)-A', 'UV18 (725)-A', 'UV19 (750)-A', 'UV20 (780)-A', 'UV21 (810)-A', 'UV22 (845)-A', 'V1 (420)-A', 'V2 (440)-A', 'V3 (460)-A', 'V4 (475)-A', 'V5 (500)-A', 'V6 (515)-A', 'V7 (530)-A', 'V8 (545)-A', 'V9 (575)-A', 'V10 (590)-A', 'V11 (605)-A', 'V12 (625)-A', 'V13 (655)-A', 'V14 (675)-A', 'V15 (700)-A', 'V16 (725)-A', 'V17 (750)-A', 'V18 (780)-A', 'V19 (810)-A', 'V20 (845)-A', 'B1 (500)-A', 'B2 (515)-A', 'B3 (530)-A', 'B4 (545)-A', 'B5 (575)-A', 'B6 (590)-A', 'B7 (605)-A', 'B8 (625)-A', 'B9 (655)-A', 'B10 (675)-A', 'B11 (700)-A', 'B12 (725)-A', 'B13 (750)-A', 'B14 (780)-A', 'B15 (810)-A', 'B16 (845)-A', 'YG1 (575)-A', 'YG2 (590)-A', 'YG3 (605)-A', 'YG4 (625)-A', 'YG5 (655)-A', 'YG6 (675)-A', 'YG7 (700)-A', 'YG8 (725)-A', 'YG9 (750)-A', 'YG10 (780)-A', 'YG11 (810)-A', 'YG12 (845)-A', 'R1 (655)-A', 'R2 (675)-A', 'R3 (700)-A', 'R4 (725)-A', 'R5 (750)-A', 'R6 (780)-A', 'R7 (810)-A', 'R8 (845)-A', 'ImgB1 (535)-H', 'ImgB2 (600)-H', 'ImgB3 (790)-H', 'UV1 (375)-H', 'UV2 (390)-H' ...
#     var: 'gene_ids', 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'leiden', 'leiden_10_0.85_renamed_colors', 'leiden_10_0.85_renamed_stats', 'leiden_10_overclustered', 'leiden_10_overclustered_colors', 'leiden_colors', 'leiden_stats', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs["double_sorted"] = (
    adata.obs["double_sorted"]
    .map({True: "True", False: "False"})
    .astype("category")
)

# %%
def sanitize_adata_keys(adata):
    adata.obs.columns = (
        adata.obs.columns
        .str.replace("/", "_", regex=False)
        .str.replace(" ", "_", regex=False)
    )

    adata.var.columns = (
        adata.var.columns
        .str.replace("/", "_", regex=False)
        .str.replace(" ", "_", regex=False)
    )

    return adata

adata = sanitize_adata_keys(adata)

# %%
adata.write_h5ad( OUT_ADATA )
! ls -lh {OUT_ADATA}
# Out:
# -rw-r--r-- 1 ubuntu ubuntu 31M Nov 28 14:51 First_salamander_batch_analyzed_with_facs.h5ad

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 352 × 12323
#     obs: 'n_genes_by_counts_x', 'log1p_n_genes_by_counts_x', 'total_counts_x', 'log1p_total_counts_x', 'pct_counts_in_top_50_genes_x', 'pct_counts_in_top_100_genes_x', 'pct_counts_in_top_200_genes_x', 'pct_counts_in_top_500_genes_x', 'geneSum_x', 'RP[LS]sum_x', 'n_genes_x', 'leiden_x', 'leiden_10_overclustered_x', 'leiden_10_0.85_x', 'leiden_10_0.85_renamed_x', 'leiden_10_0.85_0_x', 'leiden_10_0.85_0_renamed_x', 'leiden_10_0.85_1_x', 'leiden_10_0.85_1_renamed_x', 'leiden_10_0.85_2_x', 'leiden_10_0.85_2_renamed_x', 'leiden_10_0.85_3_x', 'leiden_10_0.85_3_renamed_x', 'leiden_10_0.85_4_x', 'leiden_10_0.85_4_renamed_x', 'celltype_x', 'n_genes_by_counts_y', 'log1p_n_genes_by_counts_y', 'total_counts_y', 'log1p_total_counts_y', 'pct_counts_in_top_50_genes_y', 'pct_counts_in_top_100_genes_y', 'pct_counts_in_top_200_genes_y', 'pct_counts_in_top_500_genes_y', 'geneSum_y', 'RP[LS]sum_y', 'n_genes_y', 'leiden_y', 'leiden_10_overclustered_y', 'leiden_10_0.85_y', 'leiden_10_0.85_renamed_y', 'leiden_10_0.85_0_y', 'leiden_10_0.85_0_renamed_y', 'leiden_10_0.85_1_y', 'leiden_10_0.85_1_renamed_y', 'leiden_10_0.85_2_y', 'leiden_10_0.85_2_renamed_y', 'leiden_10_0.85_3_y', 'leiden_10_0.85_3_renamed_y', 'leiden_10_0.85_4_y', 'leiden_10_0.85_4_renamed_y', 'celltype_y', 'BCset', 'plateBC', 'XC_DNBPE', 'XC_DNBPE_TS', 'WellID', 'S8_Sort', 'gate', 'phagocytosing_no_phagocytosing', 'Well_norm', 'Well', 'EventID', 'Sort_Population', 'ImagePath', 'EventIndex', 'Time', 'FSC-A', 'FSC-H', 'FSC-W', 'SSC_(Violet)-A', 'SSC_(Violet)-H', 'SSC_(Violet)-W', 'LightLoss_(Imaging)-A', 'LightLoss_(Imaging)-H', 'LightLoss_(Imaging)-W', 'SSC_(Imaging)-A', 'SSC_(Imaging)-H', 'SSC_(Imaging)-W', 'LightLoss_(Violet)-A', 'LightLoss_(Violet)-H', 'LightLoss_(Violet)-W', 'E.coli_Lysosom_Alexa_Fluor_488-A', 'L-D_eF780-right*-A', 'Size_(LightLoss_(Imaging))', 'Size_(FSC)', 'Size_(SSC_(Imaging))', 'Size_(E.coli_Lysosom_Alexa_Fluor_488)', 'Max_Intensity_(LightLoss_(Imaging))', 'Max_Intensity_(FSC)', 'Max_Intensity_(SSC_(Imaging))', 'Max_Intensity_(E.coli_Lysosom_Alexa_Fluor_488)', 'Long_Axis_Moment_(LightLoss_(Imaging))', 'Long_Axis_Moment_(FSC)', 'Long_Axis_Moment_(SSC_(Imaging))', 'Long_Axis_Moment_(E.coli_Lysosom_Alexa_Fluor_488)', 'Short_Axis_Moment_(LightLoss_(Imaging))', 'Short_Axis_Moment_(FSC)', 'Short_Axis_Moment_(SSC_(Imaging))', 'Short_Axis_Moment_(E.coli_Lysosom_Alexa_Fluor_488)', 'Center_of_Mass_(Y)_(LightLoss_(Imaging))', 'Center_of_Mass_(Y)_(FSC)', 'Center_of_Mass_(Y)_(SSC_(Imaging))', 'Center_of_Mass_(Y)_(E.coli_Lysosom_Alexa_Fluor_488)', 'Center_of_Mass_(X)_(LightLoss_(Imaging))', 'Center_of_Mass_(X)_(FSC)', 'Center_of_Mass_(X)_(SSC_(Imaging))', 'Center_of_Mass_(X)_(E.coli_Lysosom_Alexa_Fluor_488)', 'Total_Intensity_(LightLoss_(Imaging))', 'Total_Intensity_(FSC)', 'Total_Intensity_(SSC_(Imaging))', 'Total_Intensity_(E.coli_Lysosom_Alexa_Fluor_488)', 'Radial_Moment_(SSC_(Imaging))', 'Radial_Moment_(LightLoss_(Imaging))', 'Radial_Moment_(FSC)', 'Radial_Moment_(E.coli_Lysosom_Alexa_Fluor_488)', 'Eccentricity_(SSC_(Imaging))', 'Eccentricity_(LightLoss_(Imaging))', 'Eccentricity_(FSC)', 'Eccentricity_(E.coli_Lysosom_Alexa_Fluor_488)', 'Diffusivity_(SSC_(Imaging))', 'Diffusivity_(LightLoss_(Imaging))', 'Diffusivity_(FSC)', 'Diffusivity_(E.coli_Lysosom_Alexa_Fluor_488)', 'Delta_CoM_(SSC_(Imaging)_LightLoss_(Imaging))', 'Delta_CoM_(SSC_(Imaging)_FSC)', 'Delta_CoM_(SSC_(Imaging)_E.coli_Lysosom_Alexa_Fluor_488)', 'Delta_CoM_(LightLoss_(Imaging)_FSC)', 'Delta_CoM_(LightLoss_(Imaging)_E.coli_Lysosom_Alexa_Fluor_488)', 'Delta_CoM_(FSC_E.coli_Lysosom_Alexa_Fluor_488)', 'Saturated', 'Time.1', 'Sorted', 'Row', 'Column', 'ImgB1_(535)-A', 'ImgB2_(600)-A', 'ImgB3_(790)-A', 'UV1_(375)-A', 'UV2_(390)-A', 'UV3_(420)-A', 'UV4_(440)-A', 'UV5_(460)-A', 'UV6_(475)-A', 'UV7_(500)-A', 'UV8_(515)-A', 'UV9_(530)-A', 'UV10_(545)-A', 'UV11_(575)-A', 'UV12_(590)-A', 'UV13_(605)-A', 'UV14_(625)-A', 'UV15_(655)-A', 'UV16_(675)-A', 'UV17_(700)-A', 'UV18_(725)-A', 'UV19_(750)-A', 'UV20_(780)-A', 'UV21_( ...
#     var: 'gene_ids', 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'hvg', 'leiden', 'leiden_10_0.85_0_renamed_colors', 'leiden_10_0.85_1_renamed_colors', 'leiden_10_0.85_2_renamed_colors', 'leiden_10_0.85_3_renamed_colors', 'leiden_10_0.85_4_renamed_colors', 'leiden_10_0.85_renamed_colors', 'leiden_10_0.85_renamed_stats', 'leiden_10_overclustered', 'leiden_10_overclustered_colors', 'leiden_colors', 'leiden_stats', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
